# %%
# Import the required modules
import random
import json
from kafka import KafkaProducer
import time

# using datetime module
import datetime;

# Define the bootstrap servers and the topic name
bootstrap_servers = "kafka:9092"
topic = "orders"

# Create a Kafka producer with JSON value serializer
producer = KafkaProducer(bootstrap_servers=bootstrap_servers)

# Define the product IDs and the quantities
product_ids = [1001, 1002, 1003, 1004, 1005]
quantities = [1, 2, 3, 4, 5]

# Define a function to generate random event data
def generate_orders():
    current_time = time.time()
    order_id = random.randint(100000, 999999)
    product_id = random.choice(product_ids)
    quantity = random.choice(quantities)
    timestamp = datetime.datetime.fromtimestamp(current_time).strftime("%m/%d/%Y, %H:%M:%S")
    
    # Create an order dictionary
    return {"order_id": order_id, "product_id": product_id, "quantity": quantity,"timestamp": timestamp}
# Loop to generate and send events
while True:
  # Generate a random event
  order = generate_orders()
  # Print the event to the console
  print(order)
  # Send the event to the Kafka topic
    
  producer.send(topic, value=json.dumps(order).encode('utf-8'))
  time.sleep(10)
# Out:
# {'order_id': 246136, 'product_id': 1005, 'quantity': 3, 'timestamp': '02/27/2025, 21:02:33'}
# {'order_id': 652644, 'product_id': 1004, 'quantity': 5, 'timestamp': '02/27/2025, 21:02:43'}
# {'order_id': 820945, 'product_id': 1001, 'quantity': 4, 'timestamp': '02/27/2025, 21:02:53'}
# {'order_id': 702354, 'product_id': 1003, 'quantity': 3, 'timestamp': '02/27/2025, 21:03:03'}
# {'order_id': 830478, 'product_id': 1002, 'quantity': 4, 'timestamp': '02/27/2025, 21:03:13'}
# {'order_id': 476584, 'product_id': 1003, 'quantity': 5, 'timestamp': '02/27/2025, 21:03:23'}
# {'order_id': 385016, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/27/2025, 21:03:33'}
# {'order_id': 109260, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/27/2025, 21:03:43'}
# {'order_id': 961195, 'product_id': 1005, 'quantity': 1, 'timestamp': '02/27/2025, 21:03:53'}
# {'order_id': 133348, 'product_id': 1003, 'quantity': 2, 'timestamp': '02/27/2025, 21:04:03'}
# {'order_id': 751915, 'product_id': 1004, 'quantity': 4, 'timestamp': '02/27/2025, 21:04:13'}
# {'order_id': 952702, 'product_id': 1005, 'quantity': 3, 'timestamp': '02/27/2025, 21:04:23'}
# {'order_id': 992172, 'product_id': 1004, 'quantity': 1, 'timestamp': '02/27/2025, 21:04:34'}
# {'order_id': 392997, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/27/2025, 21:04:44'}
# {'order_id': 293513, 'product_id': 1005, 'quantity': 4, 'timestamp': '02/27/2025, 21:04:54'}
# {'order_id': 442423, 'product_id': 1002, 'quantity': 3, 'timestamp': '02/27/2025, 21:05:04'}
# {'order_id': 440237, 'product_id': 1005, 'quantity': 4, 'timestamp': '02/27/2025, 21:05:14'}
# {'order_id': 579057, 'product_id': 1003, 'quantity': 5, 'timestamp': '02/27/2025, 21:05:24'}
# {'order_id': 146763, 'product_id': 1002, 'quantity': 4, 'timestamp': '02/27/2025, 21:05:34'}
# {'order_id': 534550, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/27/2025, 21:05:44'}
# {'order_id': 612074, 'product_id': 1005, 'quantity': 3, 'timestamp': '02/27/2025, 21:05:54'}
# {'order_id': 157705, 'product_id': 1002, 'quantity': 4, 'timestamp': '02/27/2025, 21:06:04'}
# {'order_id': 411079, 'product_id': 1005, 'quantity': 3, 'timestamp': '02/27/2025, 21:06:14'}
# {'order_id': 992257, 'product_id': 1002, 'quantity': 2, 'timestamp': '02/27/2025, 21:06:24'}
# {'order_id': 352585, 'product_id': 1001, 'quantity': 1, 'timestamp': '02/27/2025, 21:06:34'}
# {'order_id': 808981, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/27/2025, 21:06:44'}
# {'order_id': 957809, 'product_id': 1005, 'quantity': 2, 'timestamp': '02/27/2025, 21:06:54'}
# {'order_id': 612194, 'product_id': 1001, 'quantity': 5, 'timestamp': '02/27/2025, 21:07:04'}
# {'order_id': 223780, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/27/2025, 21:07:14'}
# {'order_id': 597174, 'product_id': 1004, 'quantity': 4, 'timestamp': '02/27/2025, 21:07:24'}
# {'order_id': 225504, 'product_id': 1005, 'quantity': 5, 'timestamp': '02/27/2025, 21:07:34'}
# {'order_id': 472989, 'product_id': 1005, 'quantity': 1, 'timestamp': '02/27/2025, 21:07:44'}
# {'order_id': 673117, 'product_id': 1002, 'quantity': 1, 'timestamp': '02/27/2025, 21:07:54'}
# {'order_id': 894866, 'product_id': 1001, 'quantity': 4, 'timestamp': '02/27/2025, 21:08:04'}
# {'order_id': 345977, 'product_id': 1003, 'quantity': 1, 'timestamp': '02/27/2025, 21:08:14'}
# {'order_id': 505889, 'product_id': 1002, 'quantity': 2, 'timestamp': '02/27/2025, 21:08:24'}
# {'order_id': 714981, 'product_id': 1001, 'quantity': 4, 'timestamp': '02/27/2025, 21:08:34'}
# {'order_id': 650122, 'product_id': 1001, 'quantity': 1, 'timestamp': '02/27/2025, 21:08:44'}
# {'order_id': 534256, 'product_id': 1003, 'quantity': 2, 'timestamp': '02/27/2025, 21:08:54'}
# {'order_id': 552374, 'product_id': 1003, 'quantity': 1, 'timestamp': '02/27/2025, 21:09:04'}
# {'order_id': 129848, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/27/2025, 21:09:14'}
# {'order_id': 994299, 'product_id': 1004, 'quantity': 4, 'timestamp': '02/27/2025, 21:09:24'}
# {'order_id': 262258, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/27/2025, 21:09:34'}
# {'order_id': 541969, 'product_id': 1002, 'quantity': 1, 'timestamp': '02/27/2025, 21:09:44'}
# {'order_id': 818157, 'product_id': 1001, 'quantity': 4, 'timestamp': '02/27/2025, 21:09:54'}
# {'order_id': 428756, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/27/2025, 21:10:04'}

# %% [markdown]
# ###
