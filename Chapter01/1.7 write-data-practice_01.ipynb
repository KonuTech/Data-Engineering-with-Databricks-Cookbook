# %%
from pyspark.sql import SparkSession

spark = (SparkSession.builder
         .appName("write-data")
         .master("spark://spark-master:7077")
         .config("spark.executor.memory", "512m")
         .getOrCreate())

spark.sparkContext.setLogLevel("ERROR")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/02/24 18:55:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType

df = (spark.read.format("csv")
      .option("header", "true")
      .option("nullValue", "null")
      .option("dateFormat", "LLLL d, y")
      .load("../data/netflix_titles.csv"))

# %%
(
    df.write.format("csv")
    .option("header", "true")
    .mode("overwrite")
    .option("delimiter", ",")
    .save("../data/data_lake/netflix_csv_data")
)

# %%
(
    df.write.format("json")
    .mode("overwrite")
    .save("../data/data_lake/netflix_json_data")
)

# %%
(df.write.format("parquet") 
 .mode("overwrite") 
 .save("../data/data_lake/netflix_parquet_data"))

# %% [markdown]
# ### Write Compressed Data

# %%
(
    df.write.format("csv")
        .mode("overwrite")
        .option("header", "true")
        .option("delimiter", ",")
        .option("codec", "org.apache.hadoop.io.compress.GzipCodec")
        .save("../data/data_lake/netflix_csv_data.gz")
)

# %% [markdown]
# ### Specify the Number of Partitions

# %%
(
    df.repartition(4)
        .write.format("csv")
        .mode("overwrite")
        .option("header", "true")
        .option("delimiter", ",")
        .save("../data/data_lake/netflix_csv_data_4_part")
)

# %% [markdown]
# ### Use `coalesce()` to Reduce number fo Partitions

# %%
(df.coalesce(1)
 .write.format("csv")
 .mode("overwrite") 
 .option("header", "true")
 .option("delimiter", ",")
 .save("../data/data_lake/netflix_csv_data_whole"))

# %% [markdown]
# ### Use `partitionBy()` to write partitions based on a column

# %%
# partition the CSV data by the 'release_year' column
(df.write.format('parquet')
 .mode('overwrite')
 .partitionBy('release_year')
 .save("../data/data_lake/netflix_parquet_data_partitioned"))

# %%
spark.stop()
